# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')
f = 2*x+1
plot(f)

# %%
x = symbols('x')
f = x**3+15*x+300
plot(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = symbols('x')
#       2 f = x**3+15*x+300
#       3 plot(f)
#
# NameError: name 'symbols' is not defined

# %%
# Exercise 1: Rational number because the number is finite, the decimals eventually stop.

# %%
# Exercise 2:
value = 10**7*10**-5
print(value)
# Out:
# 100.00000000000001

# %%
# Exercise 3:
value = 81**(1/2)
print(value)
# Out:
# 9.0

# %%
# Exercise 4:
25**(3/2)
# Out:
# 125.0

# %%
# Exercise 5:
from math import exp

p = 1000
r = 0.05
n = 12
t = 3
a = p * (1 + (r / n))**(n*t)
print(a)
# Out:
# 1161.4722313334678

# %%
# Exercise 6:
a = p * exp(r*t)
p = 1000
r = 0.05
t = 3
print(a)
# Out:
# 1161.834242728283
